# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("datasets/Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Clean Columns / 'Gereksiz' Kolonları Temizlemek

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.drop(columns="Id", inplace=True)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.groupby("Species").agg(["min", "max", "std", "mean"])
# Out:
#                 SepalLengthCm                       SepalWidthCm       \
#                           min  max       std   mean          min  max
# Species
# Iris-setosa               4.3  5.8  0.352490  5.006          2.3  4.4
# Iris-versicolor           4.9  7.0  0.516171  5.936          2.0  3.4
# Iris-virginica            4.9  7.9  0.635880  6.588          2.2  3.8
#
#                                  PetalLengthCm                        \
#                       std   mean           min  max       std   mean
# Species
# Iris-setosa      0.381024  3.418           1.0  1.9  0.173511  1.464
# Iris-versicolor  0.313798  2.770           3.0  5.1  0.469911  4.260
# Iris-virginica   0.322497  2.974           4.5  6.9  0.551895  5.552
#
#                 PetalWidthCm
#                          min  max       std   mean
# Species
# Iris-setosa              0.1  0.6  0.107210  0.244
# Iris-versicolor          1.0  1.8  0.197753  1.326
# Iris-virginica           1.4  2.5  0.274650  2.026

# %%
data.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Data Visualizaton / Veri Görselleştirme

# %%
data["Id"]=data.index

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
#       Id
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 145  145
# 146  146
# 147  147
# 148  148
# 149  149
#
# [150 rows x 6 columns]

# %%
for column in data.columns[1:-1]:
    sns.scatterplot(data=data, x="Id", y=column, hue="Species")
    plt.show()

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
#       Id
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 145  145
# 146  146
# 147  147
# 148  148
# 149  149
#
# [150 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  Id
# 0            5.1           3.5            1.4           0.2  Iris-setosa   0
# 1            4.9           3.0            1.4           0.2  Iris-setosa   1
# 2            4.7           3.2            1.3           0.2  Iris-setosa   2
# 3            4.6           3.1            1.5           0.2  Iris-setosa   3
# 4            5.0           3.6            1.4           0.2  Iris-setosa   4

# %%
data.drop(["Id"], axis=1, inplace=True)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Label Encoding

# %%
le = LabelEncoder()

# %%
data["Species"] = le.fit_transform(data["Species"])

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:, :-1], data.iloc[:, -1], test_size=0.2)

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 60             5.0           2.0            3.5           1.0
# 55             5.7           2.8            4.5           1.3
# 139            6.9           3.1            5.4           2.1
# 115            6.4           3.2            5.3           2.3
# 104            6.5           3.0            5.8           2.2
# 17             5.1           3.5            1.4           0.3
# 133            6.3           2.8            5.1           1.5
# 15             5.7           4.4            1.5           0.4
# 12             4.8           3.0            1.4           0.1
# 107            7.3           2.9            6.3           1.8
# 129            7.2           3.0            5.8           1.6
# 40             5.0           3.5            1.3           0.3
# 0              5.1           3.5            1.4           0.2
# 83             6.0           2.7            5.1           1.6
# 36             5.5           3.5            1.3           0.2
# 43             5.0           3.5            1.6           0.6
# 79             5.7           2.6            3.5           1.0
# 41             4.5           2.3            1.3           0.3
# 47             4.6           3.2            1.4           0.2
# 38             4.4           3.0            1.3           0.2
# 74             6.4           2.9            4.3           1.3
# 96             5.7           2.9            4.2           1.3
# 71             6.1           2.8            4.0           1.3
# 44             5.1           3.8            1.9           0.4
# 135            7.7           3.0            6.1           2.3
# 27             5.2           3.5            1.5           0.2
# 72             6.3           2.5            4.9           1.5
# 140            6.7           3.1            5.6           2.4
# 148            6.2           3.4            5.4           2.3
# 86             6.7           3.1            4.7           1.5

# %%
y_train.value_counts()
# Out:
# 2    41
# 1    41
# 0    38
# Name: Species, dtype: int64

# %% [markdown]
# # Creating First Model

# %%
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-149-5943d1bfe3f1> in <module>
# ----> 1 import xgboost as xgb
#
# ModuleNotFoundError: No module named 'xgboost'
